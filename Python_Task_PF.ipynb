# %% [markdown]
# **Task#1**

# %%
def student(stud):
  total_student=100;
  student_Math=20;
  student_Bio=40;
  result1=student_Math+student_Bio
  print("The number of students with Math and Bio: ", result1)
  result2=total_student-result1
  print(" The number of students with Math and Bio:", result2)
  return

# %%
student(str)
# Out:
# The number of students with Math and Bio:  60
#  The number of students with Math and Bio: 40

# %% [markdown]
# **Task#2**

# %%
# To take input from the user and find number is prime number or not
num = int(input("Enter a number: "))

if num == 1:
   # check for factors
   for i in range(2,num//2):
       if (num % i) == 0:

           print(num,"is not a prime number")
   else:
       print(num,"is a prime number")
else:
   print(num,"is not a prime number")
# Out:
# Enter a number: 80
# 80 is not a prime number

# %%
#Case not prime number return the value of -1
def is_prime(n):
  for i in range(2,n):
    if (n%i) == 0:
      return -1
  return 1

# %%
is_prime(3)
# Out:
# 1

# %%
#Sum of all Prime Number
from ast import Break
num =input("Enter a number Value:")
num=int(num)
sum=0
for i in range(2,num+1):
  for j in range(2,i):
    if(i%j==0):
      Break
    else:
        print(i,"is Prime Number")
        sum =sum+i
        print("Sum of all prime number:",sum )
# Out:
# Enter a number Value:40
# 3 is Prime Number
# Sum of all prime number: 3
# 4 is Prime Number
# Sum of all prime number: 7
# 5 is Prime Number
# Sum of all prime number: 12
# 5 is Prime Number
# Sum of all prime number: 17
# 5 is Prime Number
# Sum of all prime number: 22
# 6 is Prime Number
# Sum of all prime number: 28
# 6 is Prime Number
# Sum of all prime number: 34
# 7 is Prime Number
# Sum of all prime number: 41
# 7 is Prime Number
# Sum of all prime number: 48
# 7 is Prime Number
# Sum of all prime number: 55
# 7 is Prime Number
# Sum of all prime number: 62
# 7 is Prime Number
# Sum of all prime number: 69
# 8 is Prime Number
# Sum of all prime number: 77
# 8 is Prime Number
# Sum of all prime number: 85
# 8 is Prime Number
# Sum of all prime number: 93
# 8 is Prime Number
# Sum of all prime number: 101
# 9 is Prime Number
# Sum of all prime number: 110
# 9 is Prime Number
# Sum of all prime number: 119
# 9 is Prime Number
# Sum of all prime number: 128
# 9 is Prime Number
# Sum of all prime number: 137
# 9 is Prime Number
# Sum of all prime number: 146
# 9 is Prime Number
# Sum of all prime number: 155
# 10 is Prime Number
# Sum of all prime number: 165
# 10 is Prime Number
# Sum of all prime number: 175
# 10 is Prime Number
# Sum of all prime number: 185
# 10 is Prime Number
# Sum of all prime number: 195
# 10 is Prime Number
# Sum of all prime number: 205
# 10 is Prime Number
# Sum of all prime number: 215
# 11 is Prime Number
# Sum of all prime number: 226
# 11 is Prime Number
# Sum of all prime number: 237
# 11 is Prime Number
# Sum of all prime number: 248
# 11 is Prime Number
# Sum of all prime number: 259
# 11 is Prime Number
# Sum of all prime number: 270
# 11 is Prime Number
# Sum of all prime number: 281
# 11 is Prime Number
# Sum of all prime number: 292
# 11 is Prime Number
# Sum of all prime number: 303
# 11 is Prime Number
# Sum of all prime number: 314
# 12 is Prime Number
# Sum of all prime number: 326
# 12 is Prime Number
# Sum of all prime number: 338
# 12 is Prime Number
# Sum of all prime number: 350
# 12 is Prime Number
# Sum of all prime number: 362
# 12 is Prime Number
# Sum of all prime number: 374
# 12 is Prime Number
# Sum of all prime number: 386
# 13 is Prime Number
# Sum of all prime number: 399
# 13 is Prime Number
# Sum of all prime number: 412
# 13 is Prime Number
# Sum of all prime number: 425
# 13 is Prime Number
# Sum of all prime number: 438
# 13 is Prime Number
# Sum of all prime number: 451
# 13 is Prime Number
# Sum of all prime number: 464
# 13 is Prime Number
# Sum of all prime number: 477
# 13 is Prime Number
# Sum of all prime number: 490
# 13 is Prime Number
# Sum of all prime number: 503
# 13 is Prime Number
# Sum of all prime number: 516
# 13 is Prime Number
# Sum of all prime number: 529
# 14 is Prime Number
# Sum of all prime number: 543
# 14 is Prime Number
# Sum of all prime number: 557
# 14 is Prime Number
# Sum of all prime number: 571
# 14 is Prime Number
# Sum of all prime number: 585
# 14 is Prime Number
# Sum of all prime number: 599
# 14 is Prime Number
# Sum of all prime number: 613
# 14 is Prime Number
# Sum of all prime number: 627
# 14 is Prime Number
# Sum of all prime number: 641
# 14 is Prime Number
# Sum of all prime number: 655
# 14 is Prime Number
# Sum of all prime number: 669
# 15 is Prime Number
# Sum of all prime number: 684
# 15 is Prime Number
# Sum of all prime number: 699
# 15 is Prime Number
# Sum of all prime number: 714
# 15 is Prime Number
# Sum of all prime number: 729
# 15 is Prime Number
# Sum of all prime number: 744
# 15 is Prime Number
# Sum of all prime number: 759
# 15 is Prime Number
# Sum of all prime number: 774
# 15 is Prime Number
# Sum of all prime number: 789
# 15 is Prime Number
# Sum of all prime number: 804
# 15 is Prime Number
# Sum of all prime number: 819
# 15 is Prime Number
# Sum of all prime number: 834
# 16 is Prime Number
# Sum of all prime number: 850
# 16 is Prime Number
# Sum of all prime number: 866
# 16 is Prime Number
# Sum of all prime number: 882
# 16 is Prime Number
# Sum of all prime number: 898
# 16 is Prime Number
# Sum of all prime number: 914
# 16 is Prime Number
# Sum of all prime number: 930
# 16 is Prime Number
# Sum of all prime number: 946
# 16 is Prime Number
# Sum of all prime number: 962
# 16 is Prime Number
# Sum of all prime number: 978
# 16 is Prime Number
# Sum of all prime number: 994
# 16 is Prime Number
# Sum of all prime number: 1010
# 17 is Prime Number
# Sum of all prime number: 1027
# 17 is Prime Number
# Sum of all prime number: 1044
# 17 is Prime Number
# Sum of all prime number: 1061
# 17 is Prime Number
# Sum of all prime number: 1078
# 17 is Prime Number
# Sum of all prime number: 1095
# 17 is Prime Number
# Sum of all prime number: 1112
# 17 is Prime Number
# Sum of all prime number: 1129
# 17 is Prime Number
# Sum of all prime number: 1146
# 17 is Prime Number
# Sum of all prime number: 1163
# 17 is Prime Number
# Sum of all prime number: 1180
# 17 is Prime Number
# Sum of all prime number: 1197
# 17 is Prime Number
# Sum of all prime number: 1214
# 17 is Prime Number
# Sum of all prime number: 1231
# 17 is Prime Number
# Sum of all prime number: 1248
# 17 is Prime Number
# Sum of all prime number: 1265
# 18 is Prime Number
# Sum of all prime number: 1283
# 18 is Prime Number
# Sum of all prime number: 1301
# 18 is Prime Number
# Sum of all prime number: 1319
# 18 is Prime Number
# Sum of all prime number: 1337
# 18 is Prime Number
# Sum of all prime number: 1355
# 18 is Prime Number
# Sum of all prime number: 1373
# 18 is Prime Number
# Sum of all prime number: 1391
# 18 is Prime Number
# Sum of all prime number: 1409
# 18 is Prime Number
# Sum of all prime number: 1427
# 18 is Prime Number
# Sum of all prime number: 1445
# 18 is Prime Number
# Sum of all prime number: 1463
# 18 is Prime Number
# Sum of all prime number: 1481
# 19 is Prime Number
# Sum of all prime number: 1500
# 19 is Prime Number
# Sum of all prime number: 1519
# 19 is Prime Number
# Sum of all prime number: 1538
# 19 is Prime Number
# Sum of all prime number: 1557
# 19 is Prime Number
# Sum of all prime number: 1576
# 19 is Prime Number
# Sum of all prime number: 1595
# 19 is Prime Number
# Sum of all prime number: 1614
# 19 is Prime Number
# Sum of all prime number: 1633
# 19 is Prime Number
# Sum of all prime number: 1652
# 19 is Prime Number
# Sum of all prime number: 1671
# 19 is Prime Number
# Sum of all prime number: 1690
# 19 is Prime Number
# Sum of all prime number: 1709
# 19 is Prime Number
# Sum of all prime number: 1728
# 19 is Prime Number
# Sum of all prime number: 1747
# 19 is Prime Number
# Sum of all prime number: 1766
# 19 is Prime Number
# Sum of all prime number: 1785
# 19 is Prime Number
# Sum of all prime number: 1804
# 20 is Prime Number
# Sum of all prime number: 1824
# 20 is Prime Number
# Sum of all prime number: 1844
# 20 is Prime Number
# Sum of all prime number: 1864
# 20 is Prime Number
# Sum of all prime number: 1884
# 20 is Prime Number
# Sum of all prime number: 1904
# 20 is Prime Number
# Sum of all prime number: 1924
# 20 is Prime Number
# Sum of all prime number: 1944
# 20 is Prime Number
# Sum of all prime number: 1964
# 20 is Prime Number
# Sum of all prime number: 1984
# 20 is Prime Number
# Sum of all prime number: 2004
# 20 is Prime Number
# Sum of all prime number: 2024
# 20 is Prime Number
# Sum of all prime number: 2044
# 20 is Prime Number
# Sum of all prime number: 2064
# 20 is Prime Number
# Sum of all prime number: 2084
# 21 is Prime Number
# Sum of all prime number: 2105
# 21 is Prime Number
# Sum of all prime number: 2126
# 21 is Prime Number
# Sum of all prime number: 2147
# 21 is Prime Number
# Sum of all prime number: 2168
# 21 is Prime Number
# Sum of all prime number: 2189
# 21 is Prime Number
# Sum of all prime number: 2210
# 21 is Prime Number
# Sum of all prime number: 2231
# 21 is Prime Number
# Sum of all prime number: 2252
# 21 is Prime Number
# Sum of all prime number: 2273
# 21 is Prime Number
# Sum of all prime number: 2294
# 21 is Prime Number
# Sum of all prime number: 2315
# 21 is Prime Number
# Sum of all prime number: 2336
# 21 is Prime Number
# Sum of all prime number: 2357
# 21 is Prime Number
# Sum of all prime number: 2378
# 21 is Prime Number
# Sum of all prime number: 2399
# 21 is Prime Number
# Sum of all prime number: 2420
# 21 is Prime Number
# Sum of all prime number: 2441
# 22 is Prime Number
# Sum of all prime number: 2463
# 22 is Prime Number
# Sum of all prime number: 2485
# 22 is Prime Number
# Sum of all prime number: 2507
# 22 is Prime Number
# Sum of all prime number: 2529
# 22 is Prime Number
# Sum of all prime number: 2551
# 22 is Prime Number
# Sum of all prime number: 2573
# 22 is Prime Number
# Sum of all prime number: 2595
# 22 is Prime Number
# Sum of all prime number: 2617
# 22 is Prime Number
# Sum of all prime number: 2639
# 22 is Prime Number
# Sum of all prime number: 2661
# 22 is Prime Number
# Sum of all prime number: 2683
# 22 is Prime Number
# Sum of all prime number: 2705
# 22 is Prime Number
# Sum of all prime number: 2727
# 22 is Prime Number
# Sum of all prime number: 2749
# 22 is Prime Number
# Sum of all prime number: 2771
# 22 is Prime Number
# Sum of all prime number: 2793
# 22 is Prime Number
# Sum of all prime number: 2815
# 22 is Prime Number
# Sum of all prime number: 2837
# 23 is Prime Number
# Sum of all prime number: 2860
# 23 is Prime Number
# Sum of all prime number: 2883
# 23 is Prime Number
# Sum of all prime number: 2906
# 23 is Prime Number
# Sum of all prime number: 2929
# 23 is Prime Number
# Sum of all prime number: 2952
# 23 is Prime Number
# Sum of all prime number: 2975
# 23 is Prime Number
# Sum of all prime number: 2998
# 23 is Prime Number
# Sum of all prime number: 3021
# 23 is Prime Number
# Sum of all prime number: 3044
# 23 is Prime Number
# Sum of all prime number: 3067
# 23 is Prime Number
# Sum of all prime number: 3090
# 23 is Prime Number
# Sum of all prime number: 3113
# 23 is Prime Number
# Sum of all prime number: 3136
# 23 is Prime Number
# Sum of all prime number: 3159
# 23 is Prime Number
# Sum of all prime number: 3182
# 23 is Prime Number
# Sum of all prime number: 3205
# 23 is Prime Number
# Sum of all prime number: 3228
# 23 is Prime Number
# Sum of all prime number: 3251
# 23 is Prime Number
# Sum of all prime number: 3274
# 23 is Prime Number
# Sum of all prime number: 3297
# 23 is Prime Number
# Sum of all prime number: 3320
# 24 is Prime Number
# Sum of all prime number: 3344
# 24 is Prime Number
# Sum of all prime number: 3368
# 24 is Prime Number
# Sum of all prime number: 3392
# 24 is Prime Number
# Sum of all prime number: 3416
# 24 is Prime Number
# Sum of all prime number: 3440
# 24 is Prime Number
# Sum of all prime number: 3464
# 24 is Prime Number
# Sum of all prime number: 3488
# 24 is Prime Number
# Sum of all prime number: 3512
# 24 is Prime Number
# Sum of all prime number: 3536
# 24 is Prime Number
# Sum of all prime number: 3560
# 24 is Prime Number
# Sum of all prime number: 3584
# 24 is Prime Number
# Sum of all prime number: 3608
# 24 is Prime Number
# Sum of all prime number: 3632
# 24 is Prime Number
# Sum of all prime number: 3656
# 24 is Prime Number
# Sum of all prime number: 3680
# 24 is Prime Number
# Sum of all prime number: 3704
# 25 is Prime Number
# Sum of all prime number: 3729
# 25 is Prime Number
# Sum of all prime number: 3754
# 25 is Prime Number
# Sum of all prime number: 3779
# 25 is Prime Number
# Sum of all prime number: 3804
# 25 is Prime Number
# Sum of all prime number: 3829
# 25 is Prime Number
# Sum of all prime number: 3854
# 25 is Prime Number
# Sum of all prime number: 3879
# 25 is Prime Number
# Sum of all prime number: 3904
# 25 is Prime Number
# Sum of all prime number: 3929
# 25 is Prime Number
# Sum of all prime number: 3954
# 25 is Prime Number
# Sum of all prime number: 3979
# 25 is Prime Number
# Sum of all prime number: 4004
# 25 is Prime Number
# Sum of all prime number: 4029
# 25 is Prime Number
# Sum of all prime number: 4054
# 25 is Prime Number
# Sum of all prime number: 4079
# 25 is Prime Number
# Sum of all prime number: 4104
# 25 is Prime Number
# Sum of all prime number: 4129
# 25 is Prime Number
# Sum of all prime number: 4154
# 25 is Prime Number
# Sum of all prime number: 4179
# 25 is Prime Number
# Sum of all prime number: 4204
# 25 is Prime Number
# Sum of all prime number: 4229
# 25 is Prime Number
# Sum of all prime number: 4254
# 26 is Prime Number
# Sum of all prime number: 4280
# 26 is Prime Number
# Sum of all prime number: 4306
# 26 is Prime Number
# Sum of all prime number: 4332
# 26 is Prime Number
# Sum of all prime number: 4358
# 26 is Prime Number
# Sum of all prime number: 4384
# 26 is Prime Number
# Sum of all prime number: 4410
# 26 is Prime Number
# Sum of all prime number: 4436
# 26 is Prime Number
# Sum of all prime number: 4462
# 26 is Prime Number
# Sum of all prime number: 4488
# 26 is Prime Number
# Sum of all prime number: 4514
# 26 is Prime Number
# Sum of all prime number: 4540
# 26 is Prime Number
# Sum of all prime number: 4566
# 26 is Prime Number
# Sum of all prime number: 4592
# 26 is Prime Number
# Sum of all prime number: 4618
# 26 is Prime Number
# Sum of all prime number: 4644
# 26 is Prime Number
# Sum of all prime number: 4670
# 26 is Prime Number
# Sum of all prime number: 4696
# 26 is Prime Number
# Sum of all prime number: 4722
# 26 is Prime Number
# Sum of all prime number: 4748
# 26 is Prime Number
# Sum of all prime number: 4774
# 26 is Prime Number
# Sum of all prime number: 4800
# 26 is Prime Number
# Sum of all prime number: 4826
# 27 is Prime Number
# Sum of all prime number: 4853
# 27 is Prime Number
# Sum of all prime number: 4880
# 27 is Prime Number
# Sum of all prime number: 4907
# 27 is Prime Number
# Sum of all prime number: 4934
# 27 is Prime Number
# Sum of all prime number: 4961
# 27 is Prime Number
# Sum of all prime number: 4988
# 27 is Prime Number
# Sum of all prime number: 5015
# 27 is Prime Number
# Sum of all prime number: 5042
# 27 is Prime Number
# Sum of all prime number: 5069
# 27 is Prime Number
# Sum of all prime number: 5096
# 27 is Prime Number
# Sum of all prime number: 5123
# 27 is Prime Number
# Sum of all prime number: 5150
# 27 is Prime Number
# Sum of all prime number: 5177
# 27 is Prime Number
# Sum of all prime number: 5204
# 27 is Prime Number
# Sum of all prime number: 5231
# 27 is Prime Number
# Sum of all prime number: 5258
# 27 is Prime Number
# Sum of all prime number: 5285
# 27 is Prime Number
# Sum of all prime number: 5312
# 27 is Prime Number
# Sum of all prime number: 5339
# 27 is Prime Number
# Sum of all prime number: 5366
# 27 is Prime Number
# Sum of all prime number: 5393
# 27 is Prime Number
# Sum of all prime number: 5420
# 27 is Prime Number
# Sum of all prime number: 5447
# 28 is Prime Number
# Sum of all prime number: 5475
# 28 is Prime Number
# Sum of all prime number: 5503
# 28 is Prime Number
# Sum of all prime number: 5531
# 28 is Prime Number
# Sum of all prime number: 5559
# 28 is Prime Number
# Sum of all prime number: 5587
# 28 is Prime Number
# Sum of all prime number: 5615
# 28 is Prime Number
# Sum of all prime number: 5643
# 28 is Prime Number
# Sum of all prime number: 5671
# 28 is Prime Number
# Sum of all prime number: 5699
# 28 is Prime Number
# Sum of all prime number: 5727
# 28 is Prime Number
# Sum of all prime number: 5755
# 28 is Prime Number
# Sum of all prime number: 5783
# 28 is Prime Number
# Sum of all prime number: 5811
# 28 is Prime Number
# Sum of all prime number: 5839
# 28 is Prime Number
# Sum of all prime number: 5867
# 28 is Prime Number
# Sum of all prime number: 5895
# 28 is Prime Number
# Sum of all prime number: 5923
# 28 is Prime Number
# Sum of all prime number: 5951
# 28 is Prime Number
# Sum of all prime number: 5979
# 28 is Prime Number
# Sum of all prime number: 6007
# 28 is Prime Number
# Sum of all prime number: 6035
# 28 is Prime Number
# Sum of all prime number: 6063
# 29 is Prime Number
# Sum of all prime number: 6092
# 29 is Prime Number
# Sum of all prime number: 6121
# 29 is Prime Number
# Sum of all prime number: 6150
# 29 is Prime Number
# Sum of all prime number: 6179
# 29 is Prime Number
# Sum of all prime number: 6208
# 29 is Prime Number
# Sum of all prime number: 6237
# 29 is Prime Number
# Sum of all prime number: 6266
# 29 is Prime Number
# Sum of all prime number: 6295
# 29 is Prime Number
# Sum of all prime number: 6324
# 29 is Prime Number
# Sum of all prime number: 6353
# 29 is Prime Number
# Sum of all prime number: 6382
# 29 is Prime Number
# Sum of all prime number: 6411
# 29 is Prime Number
# Sum of all prime number: 6440
# 29 is Prime Number
# Sum of all prime number: 6469
# 29 is Prime Number
# Sum of all prime number: 6498
# 29 is Prime Number
# Sum of all prime number: 6527
# 29 is Prime Number
# Sum of all prime number: 6556
# 29 is Prime Number
# Sum of all prime number: 6585
# 29 is Prime Number
# Sum of all prime number: 6614
# 29 is Prime Number
# Sum of all prime number: 6643
# 29 is Prime Number
# Sum of all prime number: 6672
# 29 is Prime Number
# Sum of all prime number: 6701
# 29 is Prime Number
# Sum of all prime number: 6730
# 29 is Prime Number
# Sum of all prime number: 6759
# 29 is Prime Number
# Sum of all prime number: 6788
# 29 is Prime Number
# Sum of all prime number: 6817
# 29 is Prime Number
# Sum of all prime number: 6846
# 30 is Prime Number
# Sum of all prime number: 6876
# 30 is Prime Number
# Sum of all prime number: 6906
# 30 is Prime Number
# Sum of all prime number: 6936
# 30 is Prime Number
# Sum of all prime number: 6966
# 30 is Prime Number
# Sum of all prime number: 6996
# 30 is Prime Number
# Sum of all prime number: 7026
# 30 is Prime Number
# Sum of all prime number: 7056
# 30 is Prime Number
# Sum of all prime number: 7086
# 30 is Prime Number
# Sum of all prime number: 7116
# 30 is Prime Number
# Sum of all prime number: 7146
# 30 is Prime Number
# Sum of all prime number: 7176
# 30 is Prime Number
# Sum of all prime number: 7206
# 30 is Prime Number
# Sum of all prime number: 7236
# 30 is Prime Number
# Sum of all prime number: 7266
# 30 is Prime Number
# Sum of all prime number: 7296
# 30 is Prime Number
# Sum of all prime number: 7326
# 30 is Prime Number
# Sum of all prime number: 7356
# 30 is Prime Number
# Sum of all prime number: 7386
# 30 is Prime Number
# Sum of all prime number: 7416
# 30 is Prime Number
# Sum of all prime number: 7446
# 30 is Prime Number
# Sum of all prime number: 7476
# 30 is Prime Number
# Sum of all prime number: 7506
# 31 is Prime Number
# Sum of all prime number: 7537
# 31 is Prime Number
# Sum of all prime number: 7568
# 31 is Prime Number
# Sum of all prime number: 7599
# 31 is Prime Number
# Sum of all prime number: 7630
# 31 is Prime Number
# Sum of all prime number: 7661
# 31 is Prime Number
# Sum of all prime number: 7692
# 31 is Prime Number
# Sum of all prime number: 7723
# 31 is Prime Number
# Sum of all prime number: 7754
# 31 is Prime Number
# Sum of all prime number: 7785
# 31 is Prime Number
# Sum of all prime number: 7816
# 31 is Prime Number
# Sum of all prime number: 7847
# 31 is Prime Number
# Sum of all prime number: 7878
# 31 is Prime Number
# Sum of all prime number: 7909
# 31 is Prime Number
# Sum of all prime number: 7940
# 31 is Prime Number
# Sum of all prime number: 7971
# 31 is Prime Number
# Sum of all prime number: 8002
# 31 is Prime Number
# Sum of all prime number: 8033
# 31 is Prime Number
# Sum of all prime number: 8064
# 31 is Prime Number
# Sum of all prime number: 8095
# 31 is Prime Number
# Sum of all prime number: 8126
# 31 is Prime Number
# Sum of all prime number: 8157
# 31 is Prime Number
# Sum of all prime number: 8188
# 31 is Prime Number
# Sum of all prime number: 8219
# 31 is Prime Number
# Sum of all prime number: 8250
# 31 is Prime Number
# Sum of all prime number: 8281
# 31 is Prime Number
# Sum of all prime number: 8312
# 31 is Prime Number
# Sum of all prime number: 8343
# 31 is Prime Number
# Sum of all prime number: 8374
# 31 is Prime Number
# Sum of all prime number: 8405
# 32 is Prime Number
# Sum of all prime number: 8437
# 32 is Prime Number
# Sum of all prime number: 8469
# 32 is Prime Number
# Sum of all prime number: 8501
# 32 is Prime Number
# Sum of all prime number: 8533
# 32 is Prime Number
# Sum of all prime number: 8565
# 32 is Prime Number
# Sum of all prime number: 8597
# 32 is Prime Number
# Sum of all prime number: 8629
# 32 is Prime Number
# Sum of all prime number: 8661
# 32 is Prime Number
# Sum of all prime number: 8693
# 32 is Prime Number
# Sum of all prime number: 8725
# 32 is Prime Number
# Sum of all prime number: 8757
# 32 is Prime Number
# Sum of all prime number: 8789
# 32 is Prime Number
# Sum of all prime number: 8821
# 32 is Prime Number
# Sum of all prime number: 8853
# 32 is Prime Number
# Sum of all prime number: 8885
# 32 is Prime Number
# Sum of all prime number: 8917
# 32 is Prime Number
# Sum of all prime number: 8949
# 32 is Prime Number
# Sum of all prime number: 8981
# 32 is Prime Number
# Sum of all prime number: 9013
# 32 is Prime Number
# Sum of all prime number: 9045
# 32 is Prime Number
# Sum of all prime number: 9077
# 32 is Prime Number
# Sum of all prime number: 9109
# 32 is Prime Number
# Sum of all prime number: 9141
# 32 is Prime Number
# Sum of all prime number: 9173
# 32 is Prime Number
# Sum of all prime number: 9205
# 32 is Prime Number
# Sum of all prime number: 9237
# 33 is Prime Number
# Sum of all prime number: 9270
# 33 is Prime Number
# Sum of all prime number: 9303
# 33 is Prime Number
# Sum of all prime number: 9336
# 33 is Prime Number
# Sum of all prime number: 9369
# 33 is Prime Number
# Sum of all prime number: 9402
# 33 is Prime Number
# Sum of all prime number: 9435
# 33 is Prime Number
# Sum of all prime number: 9468
# 33 is Prime Number
# Sum of all prime number: 9501
# 33 is Prime Number
# Sum of all prime number: 9534
# 33 is Prime Number
# Sum of all prime number: 9567
# 33 is Prime Number
# Sum of all prime number: 9600
# 33 is Prime Number
# Sum of all prime number: 9633
# 33 is Prime Number
# Sum of all prime number: 9666
# 33 is Prime Number
# Sum of all prime number: 9699
# 33 is Prime Number
# Sum of all prime number: 9732
# 33 is Prime Number
# Sum of all prime number: 9765
# 33 is Prime Number
# Sum of all prime number: 9798
# 33 is Prime Number
# Sum of all prime number: 9831
# 33 is Prime Number
# Sum of all prime number: 9864
# 33 is Prime Number
# Sum of all prime number: 9897
# 33 is Prime Number
# Sum of all prime number: 9930
# 33 is Prime Number
# Sum of all prime number: 9963
# 33 is Prime Number
# Sum of all prime number: 9996
# 33 is Prime Number
# Sum of all prime number: 10029
# 33 is Prime Number
# Sum of all prime number: 10062
# 33 is Prime Number
# Sum of all prime number: 10095
# 33 is Prime Number
# Sum of all prime number: 10128
# 33 is Prime Number
# Sum of all prime number: 10161
# 33 is Prime Number
# Sum of all prime number: 10194
# 34 is Prime Number
# Sum of all prime number: 10228
# 34 is Prime Number
# Sum of all prime number: 10262
# 34 is Prime Number
# Sum of all prime number: 10296
# 34 is Prime Number
# Sum of all prime number: 10330
# 34 is Prime Number
# Sum of all prime number: 10364
# 34 is Prime Number
# Sum of all prime number: 10398
# 34 is Prime Number
# Sum of all prime number: 10432
# 34 is Prime Number
# Sum of all prime number: 10466
# 34 is Prime Number
# Sum of all prime number: 10500
# 34 is Prime Number
# Sum of all prime number: 10534
# 34 is Prime Number
# Sum of all prime number: 10568
# 34 is Prime Number
# Sum of all prime number: 10602
# 34 is Prime Number
# Sum of all prime number: 10636
# 34 is Prime Number
# Sum of all prime number: 10670
# 34 is Prime Number
# Sum of all prime number: 10704
# 34 is Prime Number
# Sum of all prime number: 10738
# 34 is Prime Number
# Sum of all prime number: 10772
# 34 is Prime Number
# Sum of all prime number: 10806
# 34 is Prime Number
# Sum of all prime number: 10840
# 34 is Prime Number
# Sum of all prime number: 10874
# 34 is Prime Number
# Sum of all prime number: 10908
# 34 is Prime Number
# Sum of all prime number: 10942
# 34 is Prime Number
# Sum of all prime number: 10976
# 34 is Prime Number
# Sum of all prime number: 11010
# 34 is Prime Number
# Sum of all prime number: 11044
# 34 is Prime Number
# Sum of all prime number: 11078
# 34 is Prime Number
# Sum of all prime number: 11112
# 34 is Prime Number
# Sum of all prime number: 11146
# 34 is Prime Number
# Sum of all prime number: 11180
# 34 is Prime Number
# Sum of all prime number: 11214
# 35 is Prime Number
# Sum of all prime number: 11249
# 35 is Prime Number
# Sum of all prime number: 11284
# 35 is Prime Number
# Sum of all prime number: 11319
# 35 is Prime Number
# Sum of all prime number: 11354
# 35 is Prime Number
# Sum of all prime number: 11389
# 35 is Prime Number
# Sum of all prime number: 11424
# 35 is Prime Number
# Sum of all prime number: 11459
# 35 is Prime Number
# Sum of all prime number: 11494
# 35 is Prime Number
# Sum of all prime number: 11529
# 35 is Prime Number
# Sum of all prime number: 11564
# 35 is Prime Number
# Sum of all prime number: 11599
# 35 is Prime Number
# Sum of all prime number: 11634
# 35 is Prime Number
# Sum of all prime number: 11669
# 35 is Prime Number
# Sum of all prime number: 11704
# 35 is Prime Number
# Sum of all prime number: 11739
# 35 is Prime Number
# Sum of all prime number: 11774
# 35 is Prime Number
# Sum of all prime number: 11809
# 35 is Prime Number
# Sum of all prime number: 11844
# 35 is Prime Number
# Sum of all prime number: 11879
# 35 is Prime Number
# Sum of all prime number: 11914
# 35 is Prime Number
# Sum of all prime number: 11949
# 35 is Prime Number
# Sum of all prime number: 11984
# 35 is Prime Number
# Sum of all prime number: 12019
# 35 is Prime Number
# Sum of all prime number: 12054
# 35 is Prime Number
# Sum of all prime number: 12089
# 35 is Prime Number
# Sum of all prime number: 12124
# 35 is Prime Number
# Sum of all prime number: 12159
# 35 is Prime Number
# Sum of all prime number: 12194
# 35 is Prime Number
# Sum of all prime number: 12229
# 35 is Prime Number
# Sum of all prime number: 12264
# 35 is Prime Number
# Sum of all prime number: 12299
# 36 is Prime Number
# Sum of all prime number: 12335
# 36 is Prime Number
# Sum of all prime number: 12371
# 36 is Prime Number
# Sum of all prime number: 12407
# 36 is Prime Number
# Sum of all prime number: 12443
# 36 is Prime Number
# Sum of all prime number: 12479
# 36 is Prime Number
# Sum of all prime number: 12515
# 36 is Prime Number
# Sum of all prime number: 12551
# 36 is Prime Number
# Sum of all prime number: 12587
# 36 is Prime Number
# Sum of all prime number: 12623
# 36 is Prime Number
# Sum of all prime number: 12659
# 36 is Prime Number
# Sum of all prime number: 12695
# 36 is Prime Number
# Sum of all prime number: 12731
# 36 is Prime Number
# Sum of all prime number: 12767
# 36 is Prime Number
# Sum of all prime number: 12803
# 36 is Prime Number
# Sum of all prime number: 12839
# 36 is Prime Number
# Sum of all prime number: 12875
# 36 is Prime Number
# Sum of all prime number: 12911
# 36 is Prime Number
# Sum of all prime number: 12947
# 36 is Prime Number
# Sum of all prime number: 12983
# 36 is Prime Number
# Sum of all prime number: 13019
# 36 is Prime Number
# Sum of all prime number: 13055
# 36 is Prime Number
# Sum of all prime number: 13091
# 36 is Prime Number
# Sum of all prime number: 13127
# 36 is Prime Number
# Sum of all prime number: 13163
# 36 is Prime Number
# Sum of all prime number: 13199
# 36 is Prime Number
# Sum of all prime number: 13235
# 36 is Prime Number
# Sum of all prime number: 13271
# 37 is Prime Number
# Sum of all prime number: 13308
# 37 is Prime Number
# Sum of all prime number: 13345
# 37 is Prime Number
# Sum of all prime number: 13382
# 37 is Prime Number
# Sum of all prime number: 13419
# 37 is Prime Number
# Sum of all prime number: 13456
# 37 is Prime Number
# Sum of all prime number: 13493
# 37 is Prime Number
# Sum of all prime number: 13530
# 37 is Prime Number
# Sum of all prime number: 13567
# 37 is Prime Number
# Sum of all prime number: 13604
# 37 is Prime Number
# Sum of all prime number: 13641
# 37 is Prime Number
# Sum of all prime number: 13678
# 37 is Prime Number
# Sum of all prime number: 13715
# 37 is Prime Number
# Sum of all prime number: 13752
# 37 is Prime Number
# Sum of all prime number: 13789
# 37 is Prime Number
# Sum of all prime number: 13826
# 37 is Prime Number
# Sum of all prime number: 13863
# 37 is Prime Number
# Sum of all prime number: 13900
# 37 is Prime Number
# Sum of all prime number: 13937
# 37 is Prime Number
# Sum of all prime number: 13974
# 37 is Prime Number
# Sum of all prime number: 14011
# 37 is Prime Number
# Sum of all prime number: 14048
# 37 is Prime Number
# Sum of all prime number: 14085
# 37 is Prime Number
# Sum of all prime number: 14122
# 37 is Prime Number
# Sum of all prime number: 14159
# 37 is Prime Number
# Sum of all prime number: 14196
# 37 is Prime Number
# Sum of all prime number: 14233
# 37 is Prime Number
# Sum of all prime number: 14270
# 37 is Prime Number
# Sum of all prime number: 14307
# 37 is Prime Number
# Sum of all prime number: 14344
# 37 is Prime Number
# Sum of all prime number: 14381
# 37 is Prime Number
# Sum of all prime number: 14418
# 37 is Prime Number
# Sum of all prime number: 14455
# 37 is Prime Number
# Sum of all prime number: 14492
# 37 is Prime Number
# Sum of all prime number: 14529
# 37 is Prime Number
# Sum of all prime number: 14566
# 38 is Prime Number
# Sum of all prime number: 14604
# 38 is Prime Number
# Sum of all prime number: 14642
# 38 is Prime Number
# Sum of all prime number: 14680
# 38 is Prime Number
# Sum of all prime number: 14718
# 38 is Prime Number
# Sum of all prime number: 14756
# 38 is Prime Number
# Sum of all prime number: 14794
# 38 is Prime Number
# Sum of all prime number: 14832
# 38 is Prime Number
# Sum of all prime number: 14870
# 38 is Prime Number
# Sum of all prime number: 14908
# 38 is Prime Number
# Sum of all prime number: 14946
# 38 is Prime Number
# Sum of all prime number: 14984
# 38 is Prime Number
# Sum of all prime number: 15022
# 38 is Prime Number
# Sum of all prime number: 15060
# 38 is Prime Number
# Sum of all prime number: 15098
# 38 is Prime Number
# Sum of all prime number: 15136
# 38 is Prime Number
# Sum of all prime number: 15174
# 38 is Prime Number
# Sum of all prime number: 15212
# 38 is Prime Number
# Sum of all prime number: 15250
# 38 is Prime Number
# Sum of all prime number: 15288
# 38 is Prime Number
# Sum of all prime number: 15326
# 38 is Prime Number
# Sum of all prime number: 15364
# 38 is Prime Number
# Sum of all prime number: 15402
# 38 is Prime Number
# Sum of all prime number: 15440
# 38 is Prime Number
# Sum of all prime number: 15478
# 38 is Prime Number
# Sum of all prime number: 15516
# 38 is Prime Number
# Sum of all prime number: 15554
# 38 is Prime Number
# Sum of all prime number: 15592
# 38 is Prime Number
# Sum of all prime number: 15630
# 38 is Prime Number
# Sum of all prime number: 15668
# 38 is Prime Number
# Sum of all prime number: 15706
# 38 is Prime Number
# Sum of all prime number: 15744
# 38 is Prime Number
# Sum of all prime number: 15782
# 38 is Prime Number
# Sum of all prime number: 15820
# 38 is Prime Number
# Sum of all prime number: 15858
# 39 is Prime Number
# Sum of all prime number: 15897
# 39 is Prime Number
# Sum of all prime number: 15936
# 39 is Prime Number
# Sum of all prime number: 15975
# 39 is Prime Number
# Sum of all prime number: 16014
# 39 is Prime Number
# Sum of all prime number: 16053
# 39 is Prime Number
# Sum of all prime number: 16092
# 39 is Prime Number
# Sum of all prime number: 16131
# 39 is Prime Number
# Sum of all prime number: 16170
# 39 is Prime Number
# Sum of all prime number: 16209
# 39 is Prime Number
# Sum of all prime number: 16248
# 39 is Prime Number
# Sum of all prime number: 16287
# 39 is Prime Number
# Sum of all prime number: 16326
# 39 is Prime Number
# Sum of all prime number: 16365
# 39 is Prime Number
# Sum of all prime number: 16404
# 39 is Prime Number
# Sum of all prime number: 16443
# 39 is Prime Number
# Sum of all prime number: 16482
# 39 is Prime Number
# Sum of all prime number: 16521
# 39 is Prime Number
# Sum of all prime number: 16560
# 39 is Prime Number
# Sum of all prime number: 16599
# 39 is Prime Number
# Sum of all prime number: 16638
# 39 is Prime Number
# Sum of all prime number: 16677
# 39 is Prime Number
# Sum of all prime number: 16716
# 39 is Prime Number
# Sum of all prime number: 16755
# 39 is Prime Number
# Sum of all prime number: 16794
# 39 is Prime Number
# Sum of all prime number: 16833
# 39 is Prime Number
# Sum of all prime number: 16872
# 39 is Prime Number
# Sum of all prime number: 16911
# 39 is Prime Number
# Sum of all prime number: 16950
# 39 is Prime Number
# Sum of all prime number: 16989
# 39 is Prime Number
# Sum of all prime number: 17028
# 39 is Prime Number
# Sum of all prime number: 17067
# 39 is Prime Number
# Sum of all prime number: 17106
# 39 is Prime Number
# Sum of all prime number: 17145
# 39 is Prime Number
# Sum of all prime number: 17184
# 39 is Prime Number
# Sum of all prime number: 17223
# 40 is Prime Number
# Sum of all prime number: 17263
# 40 is Prime Number
# Sum of all prime number: 17303
# 40 is Prime Number
# Sum of all prime number: 17343
# 40 is Prime Number
# Sum of all prime number: 17383
# 40 is Prime Number
# Sum of all prime number: 17423
# 40 is Prime Number
# Sum of all prime number: 17463
# 40 is Prime Number
# Sum of all prime number: 17503
# 40 is Prime Number
# Sum of all prime number: 17543
# 40 is Prime Number
# Sum of all prime number: 17583
# 40 is Prime Number
# Sum of all prime number: 17623
# 40 is Prime Number
# Sum of all prime number: 17663
# 40 is Prime Number
# Sum of all prime number: 17703
# 40 is Prime Number
# Sum of all prime number: 17743
# 40 is Prime Number
# Sum of all prime number: 17783
# 40 is Prime Number
# Sum of all prime number: 17823
# 40 is Prime Number
# Sum of all prime number: 17863
# 40 is Prime Number
# Sum of all prime number: 17903
# 40 is Prime Number
# Sum of all prime number: 17943
# 40 is Prime Number
# Sum of all prime number: 17983
# 40 is Prime Number
# Sum of all prime number: 18023
# 40 is Prime Number
# Sum of all prime number: 18063
# 40 is Prime Number
# Sum of all prime number: 18103
# 40 is Prime Number
# Sum of all prime number: 18143
# 40 is Prime Number
# Sum of all prime number: 18183
# 40 is Prime Number
# Sum of all prime number: 18223
# 40 is Prime Number
# Sum of all prime number: 18263
# 40 is Prime Number
# Sum of all prime number: 18303
# 40 is Prime Number
# Sum of all prime number: 18343
# 40 is Prime Number
# Sum of all prime number: 18383
# 40 is Prime Number
# Sum of all prime number: 18423
# 40 is Prime Number
# Sum of all prime number: 18463
# 40 is Prime Number
# Sum of all prime number: 18503
